# %%
import pandas as pd
import os
from datetime import datetime
import re
import pyarrow.parquet as pq
import holidays
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse
from dateutil.parser import parse 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from statsmodels.tsa.stattools import adfuller, kpss
import numpy as np, pandas as pd
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from pmdarima.arima import ndiffs
import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARIMA

#plt.rcParams.update({'figure.figsize': (10, 7), 'figure.dpi': 120})

# %% [markdown]
# ### convert datetime to two separate columns date and time

# %%
def feature_eng(df, column):
    df['pickup_date'] = [d.date() for d in pd.to_datetime(df[column])]
    df.drop(column, axis=1, inplace=True)
    df['count'] = 1
    return df

# %%
def get_files_list(path):
    return os.listdir(path)

# %%
def update_list_files():
    list_files = get_files_list('data/')
    list_output = get_files_list('new_data/')
    list_output = [item.replace('.csv', '') for item in list_output]
    for file in list_output:
        #print(file)
        if file in list_files:
            list_files.remove(file)
            #print(len(list_files))
    return list_files

# %%
def add_holiday_column(dataset):
    us_NY_holidays = holidays.country_holidays('US', subdiv='NY')
    dataset['holiday'] = 0
    dataset['holiday'] = [1 if d in us_NY_holidays else 0 for d in dataset['pickup_date'] ]
    return dataset

# %%
def add_weekday(dataset):
    dataset['weekday'] = 0
    dataset['weekday'] = [d.weekday() for d in pd.to_datetime(dataset['pickup_date'])]
    return dataset

# %%
def trim_df(dataset):
    dataset = dataset[dataset['pickup_date'] < '2022-05-01']
    dataset = dataset[dataset['pickup_date'] > '2014-12-31']
    return dataset

# %%
def add_7days(dataset):
    yesterday_dates = dataset.pickup_date - pd.Timedelta("1 day")
    last_week_dates = dataset.pickup_date - pd.Timedelta("7 days")
    
    dataset["cases_7days"] = [dataset.new_case[dataset.pickup_date.between(yesterday, last_week)].sum()
                    for yesterday, last_week in zip(yesterday_dates, last_week_dates)]
    dataset["death_7days"] = [dataset.new_death[dataset.pickup_date.between(yesterday, last_week)].sum()
                    for yesterday, last_week in zip(yesterday_dates, last_week_dates)]
    return dataset

# %% [markdown]
# ### create light files

# %%
list_files = get_files_list('temp/')
print('number of files to read: ', len(list_files))
for file_name in list_files:
    print('reading {} file'.format(file_name))
    pfile = pq.read_table('temp/' + file_name)
#     print(pfile.column_names)
#     column = [item for item in pfile.column_names if 'pickup_datetime' in item.lower()][0]
    f =  pd.read_parquet('temp/' + file_name, engine='pyarrow')
    f.to_csv('temp_/' + file_name + '.csv')
#     f = feature_eng(f, column)
#     f = f.groupby('pickup_date').count()
#     f.to_csv('new_data/' + file_name + '.csv')     latitude longtitude
# Out:
# number of files to read:  28
# reading fhvhv_tripdata_2019-05.parquet file
# reading fhvhv_tripdata_2020-03.parquet file
# reading fhvhv_tripdata_2021-01.parquet file
# reading fhvhv_tripdata_2022-01.parquet file
# reading fhv_tripdata_2015-01.parquet file
# reading fhv_tripdata_2016-01.parquet file
# reading fhv_tripdata_2017-01.parquet file
# reading fhv_tripdata_2018-03.parquet file
# reading fhv_tripdata_2019-05.parquet file
# reading fhv_tripdata_2020-07.parquet file
# reading fhv_tripdata_2021-09.parquet file
# reading fhv_tripdata_2022-03.parquet file
# reading green_tripdata_2015-01.parquet file
# reading green_tripdata_2016-03.parquet file
# reading green_tripdata_2017-05.parquet file
# reading green_tripdata_2018-07.parquet file
# reading green_tripdata_2019-09.parquet file
# reading green_tripdata_2020-11.parquet file
# reading green_tripdata_2021-04.parquet file
# reading green_tripdata_2022-01.parquet file
# reading yellow_tripdata_2015-12.parquet file
# reading yellow_tripdata_2016-01.parquet file
# reading yellow_tripdata_2017-02.parquet file
# reading yellow_tripdata_2018-03.parquet file
# reading yellow_tripdata_2019-05.parquet file
# reading yellow_tripdata_2020-07.parquet file
# reading yellow_tripdata_2021-09.parquet file
# reading yellow_tripdata_2022-04.parquet file

# %% [markdown]
# ### load and concatenate files

# %%
if not os.path.exists('output/aggregated_files.csv'):
    full_df = pd.DataFrame()
    list_files = get_files_list('new_data/')
    for file_name in list_files:
        if 'fhvhv_' not in file_name:
            f =  pd.read_csv('new_data/' + file_name, index_col = None)
            full_df = full_df.append(f)
    full_df = trim_df(full_df)
    final_dataset = add_holiday_column(full_df)
    final_dataset = add_weekday(final_dataset)
    final_dataset = full_df.groupby('pickup_date', as_index=False, sort=False).agg({'count': \
                                                                    'sum', 'holiday': 'first', 'weekday': 'first'})
    final_dataset.to_csv('output/aggregated_files.csv', index = False)
else:
    final_dataset = pd.read_csv('output/aggregated_files.csv', index_col = None)

# %% [markdown]
# ### Merges our dataset with covid case dataset

# %%
covid_cases = pd.read_csv('source/USstat.csv', 
                          usecols = ['submission_date', 
                                     'new_case', 
                                     'new_death',
                                     'state'
                                    ], 
                          thousands = ",",
                          index_col = None,
                          dtype = {'new_case': int, 
                                   'new_death': int,
                                  }
                         )
covid_cases['submission_date'] = pd.to_datetime(covid_cases['submission_date'])
covid_cases = covid_cases[covid_cases['state'] == 'NYC']
final_dataset['pickup_date'] = pd.to_datetime(final_dataset['pickup_date'])
merged_dataset = final_dataset.merge(covid_cases.rename({'submission_date': 'pickup_date'}, axis = 1), \
                                     on = 'pickup_date', how = 'left')
# merged_dataset = merged_dataset.fillna(0)

# %%
data_for_corr = merged_dataset[merged_dataset['pickup_date'] > '2022-01-01']

# %%
data_for_corr.corr()
# Out:
#               count   holiday   weekday  new_case  new_death
# count      1.000000 -0.065172 -0.205732 -0.537930  -0.542450
# holiday   -0.065172  1.000000 -0.104713 -0.045888   0.114804
# weekday   -0.205732 -0.104713  1.000000  0.122113  -0.245231
# new_case  -0.537930 -0.045888  0.122113  1.000000   0.432119
# new_death -0.542450  0.114804 -0.245231  0.432119   1.000000

# %% [markdown]
# ### Adds 7 days new cases and new deaths

# %%
merged_dataset["cases_7days"]=merged_dataset["new_case"].rolling(7).sum()
merged_dataset["cases_7days"]=merged_dataset["cases_7days"].shift(1)

merged_dataset["death_7days"]=merged_dataset["new_death"].rolling(7).sum()
merged_dataset["death_7days"]=merged_dataset["death_7days"].shift(1)

# %%
merged_dataset['year'] = [int(year.year)-2014 for year in merged_dataset['pickup_date']]
merged_dataset.sort_values(by=['pickup_date'], inplace=True)
# merged_dataset.fillna(0, inplace = True)

# %%
print('lenght of fianl_dataset',len(final_dataset))
print('lenght of covid_cases', len(covid_cases))
print('length of merged_dataset', len(merged_dataset))
# Out:
# lenght of fianl_dataset 2677
# lenght of covid_cases 938
# length of merged_dataset 2677

# %%
merged_dataset.to_csv('mixed_data.csv')

# %% [markdown]
# ### Linear Regression for baseline

# %%
train = merged_dataset[merged_dataset['year'] < 5]
train_x = train[['holiday', 'weekday', 'cases_7days', 'death_7days']]
train_y = train['count']
test = merged_dataset[merged_dataset['year'] == 5]
test_x = test[['holiday', 'weekday', 'cases_7days', 'death_7days']]
test_y = test['count']
model = LinearRegression().fit(train_x, train_y)
model.score(train_x, train_y)
predictions = model.predict(test_x)
print(mean_absolute_error(test_y, predictions))
print(mean_squared_error(test_y, predictions))
# Out:
# 479772.3472159993
# 241004399356.06857

# %% [markdown]
# # Time series model

# %%
merged_dataset = pd.read_csv('output/aggregated_files.csv', parse_dates=['pickup_date'])
# merged_dataset = merged_dataset[merged_dataset['pickup_date'] < '2019-01-01']
merged_dataset.set_index(['pickup_date'], inplace=True)
merged_dataset.sort_index(inplace=True)

# Multiplicative Decomposition 
result_mul = seasonal_decompose(merged_dataset['count'], model='multiplicative', extrapolate_trend='freq')

# Additive Decomposition
result_add = seasonal_decompose(merged_dataset['count'], model='additive', extrapolate_trend='freq')

# Plot
plt.rcParams.update({'figure.figsize': (20,10)})
result_mul.plot().suptitle('Multiplicative Decompose', fontsize=22)
plt.savefig('decompose_mul.jpg')

result_add.plot().suptitle('Additive Decompose', fontsize=22)
plt.savefig('decompose_add.jpg')

# %% [markdown]
# ### Test if the series is stationary or not

# %%
# ADF Test
result = adfuller(merged_dataset['count'].values, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'p-value: {result[1]}')
for key, value in result[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')

# KPSS Test
result = kpss(merged_dataset['count'].values, regression='c')
print('\nKPSS Statistic: %f' % result[0])
print('p-value: %f' % result[1])
for key, value in result[3].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# ADF Statistic: -2.506560818252756
# p-value: 0.11388615685322845
# Critial Values:
#    1%, -3.434908816804013
# Critial Values:
#    5%, -2.863553406963303
# Critial Values:
#    10%, -2.5678419239852994
#
# KPSS Statistic: 4.651214
# p-value: 0.010000
# Critial Values:
#    10%, 0.347
# Critial Values:
#    5%, 0.463
# Critial Values:
#    2.5%, 0.574
# Critial Values:
#    1%, 0.739
# C:\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1875: FutureWarning: The behavior of using nlags=None will change in release 0.13.Currently nlags=None is the same as nlags="legacy", and so a sample-size lag length is used. After the next release, the default will change to be the same as nlags="auto" which uses an automatic lag length selection method. To silence this warning, either use "auto" or "legacy"
#   warnings.warn(msg, FutureWarning)
# C:\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1906: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(

# %% [markdown]
# #### so the hypothesis is rejected and times series is non-stationary
# #### Now we test to find the best d value

# %%
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':120})

# Import data
merged_dataset = pd.read_csv('output/aggregated_files.csv',  header=0)
merged_dataset = merged_dataset[merged_dataset['pickup_date'] < '2019-01-01']
merged_dataset.sort_values('pickup_date', inplace=True)
# merged_dataset.set_index(['pickup_date'], inplace=True)
dataset_lenght = len(merged_dataset)
# Original Series
fig, axes = plt.subplots(3, 2, sharex=True)
axes[0, 0].plot(merged_dataset['count']); axes[0, 0].set_title('Original Series')
plot_acf(merged_dataset['count'], lags = dataset_lenght-1, ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot(merged_dataset['count'].diff()); axes[1, 0].set_title('1st Order Differencing')
plot_acf(merged_dataset['count'].diff().dropna(), lags=dataset_lenght-2, ax=axes[1, 1])

# 2nd Differencing
axes[2, 0].plot(merged_dataset['count'].diff().diff()); axes[2, 0].set_title('2nd Order Differencing')
plot_acf(merged_dataset['count'].diff().diff().dropna(), lags = dataset_lenght-3, ax=axes[2, 1])

plt.show()

# %% [markdown]
# #### Now we transform the series to stationary

# %%
# ! pip install pmdarima
#df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/wwwusage.csv', names=['value'], header=0)
y = merged_dataset['count']

## Adf Test
print(ndiffs(y, test='adf')) 

# KPSS test
print(ndiffs(y, test='kpss')) 

# PP test:
print(ndiffs(y, test='pp'))
# Out:
# 0
# 1
# 0

# %% [markdown]
# ### Find P value

# %%
# PACF plot of 1st differenced series
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2, sharex=False)
axes[0].plot(merged_dataset['count'].diff()); axes[0].set_title('1st Differencing')
axes[1].set(ylim=(0,5))
plot_pacf(merged_dataset['count'].diff().dropna(), ax=axes[1], lags=729)

plt.show()
# Out:
# C:\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1434: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %% [markdown]
# ### Now compute the q value

# %%
# df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/austa.csv')
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})
fig, axes = plt.subplots(1, 2, sharex=False)
axes[0].plot(merged_dataset['count'].diff()); axes[0].set_title('1st Differencing')
axes[1].set(ylim=(0,1.2))
plot_acf(merged_dataset['count'].diff().dropna(), ax=axes[1], lags=dataset_lenght-2)

plt.show()

# %% [markdown]
# ### Make model

# %%
merged_dataset.head(5)
# Out:
#   pickup_date   count  holiday  weekday
# 0  2015-01-01  519577        1        3
# 1  2015-01-02  450266        0        4
# 2  2015-01-03  542131        0        5
# 3  2015-01-04  432815        0        6
# 4  2015-01-05  475444        0        0

# %%
merged_dataset = pd.read_csv('output/aggregated_files.csv',  header=0)
# merged_dataset = merged_dataset[merged_dataset['pickup_date'] < '2016-01-01']
merged_dataset.sort_values('pickup_date', inplace=True)
# 1,1,2 ARIMA Model
model = ARIMA(merged_dataset['count'], order=(1,1,1)) #p,d,q
model_fit = model.fit()
print(model_fit.summary())
# Out:
# C:\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.count   No. Observations:                 2676
# Model:                 ARIMA(1, 1, 1)   Log Likelihood              -33397.164
# Method:                       css-mle   S.D. of innovations          63654.312
# Date:                Sun, 25 Sep 2022   AIC                          66802.328
# Time:                        05:16:42   BIC                          66825.897
# Sample:                             1   HQIC                         66810.855
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          -133.1596    322.564     -0.413      0.680    -765.374     499.055
# ar.L1.D.count     0.6543      0.022     29.253      0.000       0.610       0.698
# ma.L1.D.count    -0.9097      0.012    -75.815      0.000      -0.933      -0.886
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.5284           +0.0000j            1.5284            0.0000
# MA.1            1.0993           +0.0000j            1.0993            0.0000
# -----------------------------------------------------------------------------

# %%
# Plot residual errors
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
# Actual vs Fitted
# from statsmodels.graphics.tsaplots import plot_predict
model_fit.plot_predict(dynamic=False)
plt.show()

# %% [markdown]
# ### Forcast future

# %%
# Build Model
merged_dataset = pd.read_csv('output/aggregated_files.csv',  header=0)
# train = merged_dataset[merged_dataset['pickup_date'] < '2018-12-01']['count']
# test = merged_dataset[(merged_dataset['pickup_date'] >= '2018-12-01') & (merged_dataset['pickup_date'] 
#                                                                         < '2018-12-28')]['count']

model = ARIMA(merged_dataset['count'], order=(1, 0, 0))  
fitted = model.fit(disp=-1)  
print(fitted.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  count   No. Observations:                 2677
# Model:                     ARMA(1, 0)   Log Likelihood              -33504.331
# Method:                       css-mle   S.D. of innovations          65911.220
# Date:                Sun, 25 Sep 2022   AIC                          67014.663
# Time:                        19:45:02   BIC                          67032.340
# Sample:                             0   HQIC                         67021.058
#
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        5.317e+05   6.98e+04      7.618      0.000    3.95e+05    6.68e+05
# ar.L1.count     0.9821      0.004    274.968      0.000       0.975       0.989
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0182           +0.0000j            1.0182            0.0000
# -----------------------------------------------------------------------------
# C:\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %%
# AIC = 67014.663
mae_arima = np.mean(np.abs(fitted.resid))
mae_arima
# Out:
# 43784.11381612173

# %%
# Forecast
fc, se, conf = fitted.forecast(len(test), alpha=0.05)  # 95% conf
# Make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)

# %% [markdown]
# ### SARIMA model

# %%
data.index[0]
# Out:
# datetime.date(2015, 1, 1)

# %%
# Import
data = pd.read_csv('output/aggregated_files.csv', parse_dates=['pickup_date'])
# data = data[data['pickup_date'] < '2019-01-01']
data['pickup_date'] = [d.date() for d in pd.to_datetime(data['pickup_date'])]
data.set_index(['pickup_date'], inplace=True)
data.sort_index(inplace=True)
data = data[['count']]
# data = data.fillna(0)
# Plot
fig, axes = plt.subplots(2, 1, figsize=(10,5), dpi=100, sharex=True)

# Usual Differencing
axes[0].plot(data[:], label='Original Series')
axes[0].plot(data[:].diff(1), label='Usual Differencing')
axes[0].set_title('Usual Differencing')
# axes[0].legend(loc='upper left', fontsize=10)


# Seasinal Dei
axes[1].plot(data[:], label='Original Series')
axes[1].plot(data[:].diff(12), label='Seasonal Differencing', color='green')
axes[1].set_title('Seasonal Differencing')
# plt.legend(loc='upper left', fontsize=10)
plt.suptitle('a10 - Drug Sales', fontsize=16)
plt.show()

# %%
# !pip3 install pyramid-arima
import pmdarima as pm

# Seasonal - fit stepwise auto-ARIMA
smodel = pm.auto_arima(data, start_p=1, start_q=1,
                         test='adf',
                         max_p=3, max_q=3, m=7,
                         start_P=0, seasonal=True,
                         d=None, D=1, trace=True,
                         error_action='ignore',  
                         suppress_warnings=True, 
                         stepwise=True)

smodel.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,1,1)[7] intercept   : AIC=65635.003, Time=2.73 sec
#  ARIMA(0,0,0)(0,1,0)[7] intercept   : AIC=68399.422, Time=0.19 sec
#  ARIMA(1,0,0)(1,1,0)[7] intercept   : AIC=66074.137, Time=1.23 sec
#  ARIMA(0,0,1)(0,1,1)[7] intercept   : AIC=66918.156, Time=0.97 sec
#  ARIMA(0,0,0)(0,1,0)[7]             : AIC=68397.694, Time=0.14 sec
#  ARIMA(1,0,1)(0,1,0)[7] intercept   : AIC=66647.433, Time=0.83 sec
#  ARIMA(1,0,1)(1,1,1)[7] intercept   : AIC=65636.873, Time=3.42 sec
#  ARIMA(1,0,1)(0,1,2)[7] intercept   : AIC=65636.761, Time=5.57 sec
#  ARIMA(1,0,1)(1,1,0)[7] intercept   : AIC=66068.671, Time=2.06 sec
#  ARIMA(1,0,1)(1,1,2)[7] intercept   : AIC=inf, Time=20.88 sec
#  ARIMA(1,0,0)(0,1,1)[7] intercept   : AIC=65661.924, Time=1.85 sec
#  ARIMA(2,0,1)(0,1,1)[7] intercept   : AIC=65627.110, Time=4.24 sec
#  ARIMA(2,0,1)(0,1,0)[7] intercept   : AIC=66649.433, Time=2.06 sec
#  ARIMA(2,0,1)(1,1,1)[7] intercept   : AIC=65628.993, Time=5.48 sec
#  ARIMA(2,0,1)(0,1,2)[7] intercept   : AIC=65629.107, Time=7.45 sec
#  ARIMA(2,0,1)(1,1,0)[7] intercept   : AIC=66068.833, Time=4.39 sec
#  ARIMA(2,0,1)(1,1,2)[7] intercept   : AIC=inf, Time=22.16 sec
#  ARIMA(2,0,0)(0,1,1)[7] intercept   : AIC=65639.924, Time=2.48 sec
#  ARIMA(3,0,1)(0,1,1)[7] intercept   : AIC=65621.665, Time=7.88 sec
#  ARIMA(3,0,1)(0,1,0)[7] intercept   : AIC=66650.351, Time=2.46 sec
#  ARIMA(3,0,1)(1,1,1)[7] intercept   : AIC=65623.646, Time=8.91 sec
#  ARIMA(3,0,1)(0,1,2)[7] intercept   : AIC=65623.640, Time=14.05 sec
#  ARIMA(3,0,1)(1,1,0)[7] intercept   : AIC=66068.925, Time=6.80 sec
#  ARIMA(3,0,1)(1,1,2)[7] intercept   : AIC=inf, Time=25.43 sec
#  ARIMA(3,0,0)(0,1,1)[7] intercept   : AIC=65625.149, Time=2.86 sec
#  ARIMA(3,0,2)(0,1,1)[7] intercept   : AIC=65589.247, Time=7.44 sec
#  ARIMA(3,0,2)(0,1,0)[7] intercept   : AIC=66545.821, Time=8.09 sec
#  ARIMA(3,0,2)(1,1,1)[7] intercept   : AIC=65591.120, Time=9.81 sec
#  ARIMA(3,0,2)(0,1,2)[7] intercept   : AIC=65591.230, Time=14.55 sec
#  ARIMA(3,0,2)(1,1,0)[7] intercept   : AIC=66056.621, Time=5.92 sec
#  ARIMA(3,0,2)(1,1,2)[7] intercept   : AIC=inf, Time=35.73 sec
#  ARIMA(2,0,2)(0,1,1)[7] intercept   : AIC=65618.591, Time=6.56 sec
#  ARIMA(3,0,3)(0,1,1)[7] intercept   : AIC=65445.369, Time=19.09 sec
#  ARIMA(3,0,3)(0,1,0)[7] intercept   : AIC=inf, Time=13.94 sec
#  ARIMA(3,0,3)(1,1,1)[7] intercept   : AIC=65447.433, Time=19.21 sec
#  ARIMA(3,0,3)(0,1,2)[7] intercept   : AIC=65447.222, Time=27.04 sec
#  ARIMA(3,0,3)(1,1,0)[7] intercept   : AIC=inf, Time=18.25 sec
#  ARIMA(3,0,3)(1,1,2)[7] intercept   : AIC=inf, Time=34.50 sec
#  ARIMA(2,0,3)(0,1,1)[7] intercept   : AIC=65508.058, Time=16.18 sec
#  ARIMA(3,0,3)(0,1,1)[7]             : AIC=65428.763, Time=11.53 sec
#  ARIMA(3,0,3)(0,1,0)[7]             : AIC=inf, Time=10.87 sec
#  ARIMA(3,0,3)(1,1,1)[7]             : AIC=65429.641, Time=11.74 sec
#  ARIMA(3,0,3)(0,1,2)[7]             : AIC=65429.636, Time=20.20 sec
#  ARIMA(3,0,3)(1,1,0)[7]             : AIC=inf, Time=20.29 sec
#  ARIMA(3,0,3)(1,1,2)[7]             : AIC=65430.881, Time=32.61 sec
#  ARIMA(2,0,3)(0,1,1)[7]             : AIC=65485.893, Time=14.22 sec
#  ARIMA(3,0,2)(0,1,1)[7]             : AIC=65568.290, Time=16.24 sec
#  ARIMA(2,0,2)(0,1,1)[7]             : AIC=65594.303, Time=6.53 sec
#
# Best model:  ARIMA(3,0,3)(0,1,1)[7]
# Total fit time: 537.166 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                 2677
# Model:             SARIMAX(3, 0, 3)x(0, 1, [1], 7)   Log Likelihood              -32706.382
# Date:                             Sun, 25 Sep 2022   AIC                          65428.763
# Time:                                     05:32:24   BIC                          65475.882
# Sample:                                 01-01-2015   HQIC                         65445.812
#                                       - 04-30-2022
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5956      0.371      1.606      0.108      -0.131       1.323
# ar.L2          0.8082      0.485      1.665      0.096      -0.143       1.759
# ar.L3         -0.4266      0.145     -2.951      0.003      -0.710      -0.143
# ma.L1          0.1665      0.371      0.449      0.654      -0.561       0.894
# ma.L2         -0.6630      0.213     -3.110      0.002      -1.081      -0.245
# ma.L3         -0.0221      0.044     -0.501      0.617      -0.109       0.065
# ma.S.L7       -0.9082      0.012    -75.039      0.000      -0.932      -0.884
# sigma2      3.292e+09   8.27e-10   3.98e+18      0.000    3.29e+09    3.29e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.19   Jarque-Bera (JB):            441109.40
# Prob(Q):                              0.66   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.05   Skew:                            -3.64
# Prob(H) (two-sided):                  0.00   Kurtosis:                        65.55
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.49e+34. Standard errors may be unstable.
# """

# %%
# Forecast
n_periods = 90
fitted, confint = smodel.predict(n_periods=n_periods, return_conf_int=True)
index_of_fc = pd.date_range(data.index[-1], periods = n_periods, freq='D')

# make series for plotting purpose
fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.rcParams["figure.figsize"] = (20,5)
plt.plot(data)
plt.plot(fitted_series, color='darkgreen')
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("SARIMA - Final Forecast")
plt.show()

# %%
data = pd.read_csv('output/aggregated_files.csv', parse_dates=['pickup_date'])
data.set_index(['pickup_date'], inplace=True)
data = data[['count']].plot()
plt.show()

# %% [markdown]
# ### SARIMAX

# %%
# Import
data = pd.read_csv('output/aggregated_files.csv', parse_dates=['pickup_date'])
# data = data[data['pickup_date'] < '2017-01-01']
data['pickup_date'] = [d.date() for d in pd.to_datetime(data['pickup_date'])]

# %%
covid_cases = pd.read_csv('source/USstat.csv', 
                          usecols = ['submission_date', 
                                     'new_case', 
                                     'new_death',
                                     'state'
                                    ], 
                          thousands = ",",
                          index_col = None,
                          dtype = {'new_case': int, 
                                   'new_death': int,
                                  }
                         )
covid_cases['submission_date'] = pd.to_datetime(covid_cases['submission_date'])
covid_cases = covid_cases[covid_cases['state'] == 'NY']
data['pickup_date'] = pd.to_datetime(data['pickup_date'])
merged_dataset = data.merge(covid_cases.rename({'submission_date': 'pickup_date'}, axis = 1), \
                                     on = 'pickup_date', how = 'left')
merged_dataset = merged_dataset.fillna(0)

# %%
merged_dataset["cases_7days"]=merged_dataset["new_case"].rolling(7).sum()
merged_dataset["cases_7days"]=merged_dataset["cases_7days"].shift(1)

merged_dataset["death_7days"]=merged_dataset["new_death"].rolling(7).sum()
merged_dataset["death_7days"]=merged_dataset["death_7days"].shift(1)

merged_dataset.set_index(['pickup_date'], inplace=True)
merged_dataset.sort_index(inplace=True)

# %%
exog_full = merged_dataset[['holiday', 'cases_7days', 'death_7days']].copy()
exog_full.fillna(0, inplace=True)
exog_half = exog_full[['death_7days', 'cases_7days']]
exog_orig = merged_dataset[['holiday', 'new_case', 'new_death']].copy()
exog_orig.fillna(0, inplace=True)

# %% [markdown]
# ### Sarimax with all exogenous

# %%
sarimax_full = sm.tsa.statespace.SARIMAX(merged_dataset[['count']],order=(5,1,0),seasonal_order=(1,0,1,7),exog = exog_full
                                    ,
                                enforce_stationarity=False, enforce_invertibility=False,freq='D').fit()
sarimax_full.summary()
# Out:
# C:\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                               count   No. Observations:                 2677
# Model:             SARIMAX(5, 1, 0)x(1, 0, [1], 7)   Log Likelihood              -32628.565
# Date:                             Thu, 29 Sep 2022   AIC                          65279.130
# Time:                                     18:35:02   BIC                          65343.893
# Sample:                                 01-01-2015   HQIC                         65302.566
#                                       - 04-30-2022
# Covariance Type:                               opg
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# holiday     -4.515e+04   3973.520    -11.362      0.000   -5.29e+04   -3.74e+04
# cases_7days    -1.3277      0.520     -2.552      0.011      -2.348      -0.308
# death_7days   -22.4606    178.462     -0.126      0.900    -372.241     327.319
# ar.L1          -0.1964      0.009    -22.797      0.000      -0.213      -0.180
# ar.L2          -0.1880      0.013    -14.050      0.000      -0.214      -0.162
# ar.L3          -0.1189      0.019     -6.277      0.000      -0.156      -0.082
# ar.L4          -0.0913      0.018     -5.110      0.000      -0.126      -0.056
# ar.L5          -0.0340      0.021     -1.643      0.100      -0.074       0.007
# ar.S.L7         0.9832      0.004    246.077      0.000       0.975       0.991
# ma.S.L7        -0.8491      0.011    -78.750      0.000      -0.870      -0.828
# sigma2       3.218e+09      0.085   3.81e+10      0.000    3.22e+09    3.22e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.19   Jarque-Bera (JB):            420306.08
# Prob(Q):                              0.67   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.05   Skew:                            -3.32
# Prob(H) (two-sided):                  0.00   Kurtosis:                        64.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.58e+25. Standard errors may be unstable.
# """

# %%
# AIC = 65956.134
mae_full = np.mean(np.abs(sarimax_full.resid))
mae_full
# Out:
# 26041.63000667047

# %%
# Forecast
n_periods = 100
length = len(merged_dataset)
plt.rcParams["figure.figsize"] = (20,5)
fitted_series = sarimax_full.predict()[-100:]
# Plot
plt.plot(merged_dataset[merged_dataset.index > '2021-08-25']['count'], label='real data')
plt.plot(fitted_series, color='red', label='prediction')
plt.legend()

plt.title("SARIMAX Forecast of the taxi mobility in last 100 days")
plt.savefig('prediction.jpg')

# %% [markdown]
# ### Sarimax with original death and new case

# %%
sarimax_full = sm.tsa.statespace.SARIMAX(merged_dataset[['count']],order=(5,1,0),seasonal_order=(1,0,1,7),exog = exog_orig,
                                enforce_stationarity=False, enforce_invertibility=False,freq='D').fit()
sarimax_full.summary()
# Out:
# C:\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                               count   No. Observations:                 2677
# Model:             SARIMAX(5, 1, 0)x(1, 0, [1], 7)   Log Likelihood              -32630.947
# Date:                             Thu, 29 Sep 2022   AIC                          65283.895
# Time:                                     19:15:23   BIC                          65348.658
# Sample:                                 01-01-2015   HQIC                         65307.331
#                                       - 04-30-2022
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# holiday    -4.498e+04   3963.936    -11.347      0.000   -5.27e+04   -3.72e+04
# new_case      -0.1819      4.865     -0.037      0.970      -9.717       9.353
# new_death     10.2036    240.090      0.042      0.966    -460.365     480.772
# ar.L1         -0.1977      0.008    -23.300      0.000      -0.214      -0.181
# ar.L2         -0.1899      0.013    -14.368      0.000      -0.216      -0.164
# ar.L3         -0.1211      0.019     -6.539      0.000      -0.157      -0.085
# ar.L4         -0.0937      0.018     -5.317      0.000      -0.128      -0.059
# ar.L5         -0.0358      0.019     -1.873      0.061      -0.073       0.002
# ar.S.L7        0.9832      0.004    257.690      0.000       0.976       0.991
# ma.S.L7       -0.8500      0.011    -79.961      0.000      -0.871      -0.829
# sigma2      3.201e+09      0.083   3.87e+10      0.000     3.2e+09     3.2e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.20   Jarque-Bera (JB):            426003.34
# Prob(Q):                              0.66   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.05   Skew:                            -3.38
# Prob(H) (two-sided):                  0.00   Kurtosis:                        64.58
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.12e+25. Standard errors may be unstable.
# """

# %%
# AIC = 65956.134
mae_full = np.mean(np.abs(sarimax_full.resid))
mae_full
# Out:
# 26041.63000667047

# %%
# Forecast
n_periods = 100
length = len(merged_dataset)
plt.rcParams["figure.figsize"] = (20,5)
fitted_series = sarimax_full.predict()[-100:]
# Plot
plt.plot(merged_dataset[merged_dataset.index > '2021-08-25']['count'], label='real data')
plt.plot(fitted_series, color='red', label='prediction')
plt.legend()

plt.title("SARIMAX Forecast of the taxi mobility in last 100 days")
plt.savefig('prediction.jpg')

# %% [markdown]
# ### Sarimax with some exogenous

# %%
sarimax_half = sm.tsa.statespace.SARIMAX(merged_dataset[['count']],order=(5,1,0),seasonal_order=(1,0,1,7),exog = exog_half,
                                enforce_stationarity=False, enforce_invertibility=False,freq='D').fit()
sarimax_half.summary()
# Out:
# C:\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                               count   No. Observations:                 2677
# Model:             SARIMAX(5, 1, 0)x(1, 0, [1], 7)   Log Likelihood              -32663.750
# Date:                             Thu, 29 Sep 2022   AIC                          65347.500
# Time:                                     18:37:30   BIC                          65406.376
# Sample:                                 01-01-2015   HQIC                         65368.806
#                                       - 04-30-2022
# Covariance Type:                               opg
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# death_7days   -18.9136    189.168     -0.100      0.920    -389.676     351.849
# cases_7days    -1.2674      0.539     -2.350      0.019      -2.324      -0.211
# ar.L1          -0.2024      0.009    -23.246      0.000      -0.219      -0.185
# ar.L2          -0.1748      0.014    -12.695      0.000      -0.202      -0.148
# ar.L3          -0.1206      0.020     -6.064      0.000      -0.160      -0.082
# ar.L4          -0.1025      0.017     -5.872      0.000      -0.137      -0.068
# ar.L5          -0.0381      0.020     -1.876      0.061      -0.078       0.002
# ar.S.L7         0.9852      0.004    255.015      0.000       0.978       0.993
# ma.S.L7        -0.8582      0.011    -75.163      0.000      -0.881      -0.836
# sigma2       3.311e+09   4.95e-05   6.69e+13      0.000    3.31e+09    3.31e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.16   Jarque-Bera (JB):            397570.95
# Prob(Q):                              0.68   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.05   Skew:                            -3.32
# Prob(H) (two-sided):                  0.00   Kurtosis:                        62.48
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.1e+30. Standard errors may be unstable.
# """

# %%
# AIC = 65659.847
mae_half = np.mean(np.abs(sarimax_half.resid))
mae_half
# Out:
# 26347.729761153136

# %%
sarimax_light = sm.tsa.statespace.SARIMAX(merged_dataset[['count']],order=(5,1,0),seasonal_order=(1,0,1,7),
                                enforce_stationarity=False, enforce_invertibility=False,freq='D').fit()
sarimax_light.summary()
# Out:
# C:\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                               count   No. Observations:                 2677
# Model:             SARIMAX(5, 1, 0)x(1, 0, [1], 7)   Log Likelihood              -32665.827
# Date:                             Thu, 29 Sep 2022   AIC                          65347.653
# Time:                                     18:39:01   BIC                          65394.754
# Sample:                                 01-01-2015   HQIC                         65364.698
#                                       - 04-30-2022
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2035      0.009    -23.710      0.000      -0.220      -0.187
# ar.L2         -0.1765      0.014    -12.958      0.000      -0.203      -0.150
# ar.L3         -0.1225      0.020     -6.268      0.000      -0.161      -0.084
# ar.L4         -0.1044      0.017     -6.070      0.000      -0.138      -0.071
# ar.L5         -0.0399      0.019     -2.110      0.035      -0.077      -0.003
# ar.S.L7        0.9853      0.004    268.362      0.000       0.978       0.992
# ma.S.L7       -0.8589      0.011    -76.217      0.000      -0.881      -0.837
# sigma2      3.294e+09   4.86e-12   6.78e+20      0.000    3.29e+09    3.29e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.17   Jarque-Bera (JB):            402679.56
# Prob(Q):                              0.68   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.05   Skew:                            -3.37
# Prob(H) (two-sided):                  0.00   Kurtosis:                        62.85
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.6e+34. Standard errors may be unstable.
# """

# %%
# AIC = 65663.930
mae_light = np.mean(np.abs(sarimax_light.resid))
mae_light
# Out:
# 26193.89765847856

# %%
# !pip3 install pyramid-arima
import pmdarima as pm

# Seasonal - fit stepwise auto-ARIMA
smodel_full = pm.auto_arima(merged_dataset[['count']], exogenous=merged_dataset[['holiday', 'cases_7days', 'death_7days']],
                         test='adf',
                         m=7,
                         error_action='ignore',  
                         trace=True 
                         )

smodel_full.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=inf, Time=11.60 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=67087.113, Time=0.13 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=66474.364, Time=0.89 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=66706.847, Time=1.73 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=67085.123, Time=0.14 sec
#  ARIMA(1,1,0)(0,0,0)[7] intercept   : AIC=67083.241, Time=0.32 sec
#  ARIMA(1,1,0)(2,0,0)[7] intercept   : AIC=66259.851, Time=1.71 sec
#  ARIMA(1,1,0)(2,0,1)[7] intercept   : AIC=65954.154, Time=3.65 sec
#  ARIMA(1,1,0)(1,0,1)[7] intercept   : AIC=65953.063, Time=2.02 sec
#  ARIMA(1,1,0)(0,0,1)[7] intercept   : AIC=66707.095, Time=0.73 sec
#  ARIMA(1,1,0)(1,0,2)[7] intercept   : AIC=65954.172, Time=3.67 sec
#  ARIMA(1,1,0)(0,0,2)[7] intercept   : AIC=66531.991, Time=1.53 sec
#  ARIMA(1,1,0)(2,0,2)[7] intercept   : AIC=65956.676, Time=2.79 sec
#  ARIMA(0,1,0)(1,0,1)[7] intercept   : AIC=65989.941, Time=1.55 sec
#  ARIMA(2,1,0)(1,0,1)[7] intercept   : AIC=65861.854, Time=2.52 sec
#  ARIMA(2,1,0)(0,0,1)[7] intercept   : AIC=66603.967, Time=1.01 sec
#  ARIMA(2,1,0)(1,0,0)[7] intercept   : AIC=66390.814, Time=1.33 sec
#  ARIMA(2,1,0)(2,0,1)[7] intercept   : AIC=65863.093, Time=5.44 sec
#  ARIMA(2,1,0)(1,0,2)[7] intercept   : AIC=65863.013, Time=4.56 sec
#  ARIMA(2,1,0)(0,0,0)[7] intercept   : AIC=66930.845, Time=0.48 sec
#  ARIMA(2,1,0)(0,0,2)[7] intercept   : AIC=66432.557, Time=1.77 sec
#  ARIMA(2,1,0)(2,0,0)[7] intercept   : AIC=66175.705, Time=2.13 sec
#  ARIMA(2,1,0)(2,0,2)[7] intercept   : AIC=65864.457, Time=4.31 sec
#  ARIMA(3,1,0)(1,0,1)[7] intercept   : AIC=65798.894, Time=3.99 sec
#  ARIMA(3,1,0)(0,0,1)[7] intercept   : AIC=66526.975, Time=1.28 sec
#  ARIMA(3,1,0)(1,0,0)[7] intercept   : AIC=66339.458, Time=1.55 sec
#  ARIMA(3,1,0)(2,0,1)[7] intercept   : AIC=65800.622, Time=6.66 sec
#  ARIMA(3,1,0)(1,0,2)[7] intercept   : AIC=65800.570, Time=5.24 sec
#  ARIMA(3,1,0)(0,0,0)[7] intercept   : AIC=66818.994, Time=0.74 sec
#  ARIMA(3,1,0)(0,0,2)[7] intercept   : AIC=66366.755, Time=2.00 sec
#  ARIMA(3,1,0)(2,0,0)[7] intercept   : AIC=66123.023, Time=2.85 sec
#  ARIMA(3,1,0)(2,0,2)[7] intercept   : AIC=65801.527, Time=5.05 sec
#  ARIMA(4,1,0)(1,0,1)[7] intercept   : AIC=65703.024, Time=4.63 sec
#  ARIMA(4,1,0)(0,0,1)[7] intercept   : AIC=66386.211, Time=1.58 sec
#  ARIMA(4,1,0)(1,0,0)[7] intercept   : AIC=66247.591, Time=1.96 sec
#  ARIMA(4,1,0)(2,0,1)[7] intercept   : AIC=65705.017, Time=7.78 sec
#  ARIMA(4,1,0)(1,0,2)[7] intercept   : AIC=65704.973, Time=6.01 sec
#  ARIMA(4,1,0)(0,0,0)[7] intercept   : AIC=66604.806, Time=1.05 sec
#  ARIMA(4,1,0)(0,0,2)[7] intercept   : AIC=66249.141, Time=2.58 sec
#  ARIMA(4,1,0)(2,0,0)[7] intercept   : AIC=66042.016, Time=3.60 sec
#  ARIMA(4,1,0)(2,0,2)[7] intercept   : AIC=65702.779, Time=7.31 sec
#  ARIMA(5,1,0)(2,0,2)[7] intercept   : AIC=inf, Time=23.78 sec
#  ARIMA(4,1,1)(2,0,2)[7] intercept   : AIC=inf, Time=21.71 sec
#  ARIMA(3,1,1)(2,0,2)[7] intercept   : AIC=inf, Time=19.69 sec
#  ARIMA(5,1,1)(2,0,2)[7] intercept   : AIC=inf, Time=24.45 sec
#  ARIMA(4,1,0)(2,0,2)[7]             : AIC=65699.365, Time=6.36 sec
#  ARIMA(4,1,0)(1,0,2)[7]             : AIC=65697.208, Time=5.84 sec
#  ARIMA(4,1,0)(0,0,2)[7]             : AIC=66247.144, Time=2.26 sec
#  ARIMA(4,1,0)(1,0,1)[7]             : AIC=65695.435, Time=4.19 sec
#  ARIMA(4,1,0)(0,0,1)[7]             : AIC=66384.212, Time=1.42 sec
#  ARIMA(4,1,0)(1,0,0)[7]             : AIC=66245.580, Time=1.72 sec
#  ARIMA(4,1,0)(2,0,1)[7]             : AIC=65697.196, Time=7.50 sec
#  ARIMA(4,1,0)(0,0,0)[7]             : AIC=66602.808, Time=0.92 sec
#  ARIMA(4,1,0)(2,0,0)[7]             : AIC=66040.009, Time=2.98 sec
#  ARIMA(3,1,0)(1,0,1)[7]             : AIC=65795.468, Time=3.68 sec
#  ARIMA(5,1,0)(1,0,1)[7]             : AIC=65593.680, Time=5.89 sec
#  ARIMA(5,1,0)(0,0,1)[7]             : AIC=66216.521, Time=1.68 sec
#  ARIMA(5,1,0)(1,0,0)[7]             : AIC=66166.062, Time=2.33 sec
#  ARIMA(5,1,0)(2,0,1)[7]             : AIC=65595.654, Time=9.13 sec
#  ARIMA(5,1,0)(1,0,2)[7]             : AIC=65595.655, Time=6.98 sec
#  ARIMA(5,1,0)(0,0,0)[7]             : AIC=66281.345, Time=1.05 sec
#  ARIMA(5,1,0)(0,0,2)[7]             : AIC=66127.387, Time=2.54 sec
#  ARIMA(5,1,0)(2,0,0)[7]             : AIC=65978.733, Time=4.26 sec
#  ARIMA(5,1,0)(2,0,2)[7]             : AIC=65597.494, Time=7.43 sec
#  ARIMA(5,1,1)(1,0,1)[7]             : AIC=inf, Time=12.20 sec
#  ARIMA(4,1,1)(1,0,1)[7]             : AIC=65678.751, Time=11.34 sec
#  ARIMA(5,1,0)(1,0,1)[7] intercept   : AIC=65608.837, Time=5.37 sec
#
# Best model:  ARIMA(5,1,0)(1,0,1)[7]
# Total fit time: 318.704 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                 2677
# Model:             SARIMAX(5, 1, 0)x(1, 0, [1], 7)   Log Likelihood              -32788.840
# Date:                             Thu, 29 Sep 2022   AIC                          65593.680
# Time:                                     18:22:01   BIC                          65640.817
# Sample:                                 01-01-2015   HQIC                         65610.734
#                                       - 04-30-2022
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2016      0.009    -23.383      0.000      -0.218      -0.185
# ar.L2         -0.1748      0.014    -12.878      0.000      -0.201      -0.148
# ar.L3         -0.1444      0.020     -7.179      0.000      -0.184      -0.105
# ar.L4         -0.1228      0.017     -7.279      0.000      -0.156      -0.090
# ar.L5         -0.0574      0.019     -3.013      0.003      -0.095      -0.020
# ar.S.L7        0.9926      0.003    362.471      0.000       0.987       0.998
# ma.S.L7       -0.9300      0.013    -71.078      0.000      -0.956      -0.904
# sigma2      3.294e+09   4.77e-12   6.91e+20      0.000    3.29e+09    3.29e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):            437946.22
# Prob(Q):                              0.82   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.05   Skew:                            -3.44
# Prob(H) (two-sided):                  0.00   Kurtosis:                        65.29
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 6.29e+34. Standard errors may be unstable.
# """

# %%
mae = np.mean(np.abs(smodel_full.resid()))
mae

# %%
# Forecast
n_periods = 100
length = len(merged_dataset)
fitted, confint = smodel.predict_in_sample(# n_periods=n_periods, 
                                  #exogenous=np.tile(seasonal_index.value, 2).reshape(-1,1), 
                                  return_conf_int=True)

index_of_fc = pd.date_range(merged_dataset.index[-100], periods = n_periods, freq='D')
plt.rcParams["figure.figsize"] = (20,5)

# make series for plotting purpose
fitted_series = pd.Series(fitted, index=index_of_fc)
# lower_series = pd.Series(confint[:, 0], index=index_of_fc)
# upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.plot(merged_dataset[merged_dataset.index > '2021-08-25']['count'], label='real data')
plt.plot(fitted_series, color='red', label='prediction')
plt.legend()
# plt.fill_between(lower_series.index, 
#                  lower_series, 
#                  upper_series, 
#                  color='k', alpha=.15)

plt.title("SARIMAX Forecast of the taxi mobility in last 100 days")
plt.savefig('prediction.jpg')

# %%
data = pd.read_csv('output/aggregated_files.csv', parse_dates=['pickup_date'])
# data = data[data['pickup_date'] < '2017-01-01']
data.set_index(['pickup_date'], inplace=True)
data = data[['count']].plot()
plt.show()

# %% [markdown]
# ### Sarimax with exogenous holiday and death_7days

# %%
# !pip3 install pyramid-arima
import pmdarima as pm

# Seasonal - fit stepwise auto-ARIMA
smodel_half = pm.auto_arima(merged_dataset[['count']], exogenous=merged_dataset[['holiday', 'death_7days']],
                         start_p=1, start_q=1,
                         test='adf',
                         max_p=3, max_q=3, m=7,
                         start_P=0, seasonal=True,
                         d=None, D=1, trace=True,
                         error_action='ignore',  
                         suppress_warnings=True, 
                         stepwise=True)

#smodel_half.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,1,1)[7] intercept   : AIC=65635.003, Time=2.50 sec
#  ARIMA(0,0,0)(0,1,0)[7] intercept   : AIC=68399.422, Time=0.15 sec
#  ARIMA(1,0,0)(1,1,0)[7] intercept   : AIC=66074.137, Time=1.18 sec
#  ARIMA(0,0,1)(0,1,1)[7] intercept   : AIC=66918.156, Time=0.87 sec
#  ARIMA(0,0,0)(0,1,0)[7]             : AIC=68397.694, Time=0.15 sec
#  ARIMA(1,0,1)(0,1,0)[7] intercept   : AIC=66647.433, Time=0.68 sec
#  ARIMA(1,0,1)(1,1,1)[7] intercept   : AIC=65636.873, Time=2.48 sec
#  ARIMA(1,0,1)(0,1,2)[7] intercept   : AIC=65636.761, Time=4.29 sec
#  ARIMA(1,0,1)(1,1,0)[7] intercept   : AIC=66068.671, Time=1.57 sec
#  ARIMA(1,0,1)(1,1,2)[7] intercept   : AIC=inf, Time=17.21 sec
#  ARIMA(1,0,0)(0,1,1)[7] intercept   : AIC=65661.924, Time=1.60 sec
#  ARIMA(2,0,1)(0,1,1)[7] intercept   : AIC=65627.110, Time=3.35 sec
#  ARIMA(2,0,1)(0,1,0)[7] intercept   : AIC=66649.433, Time=1.54 sec
#  ARIMA(2,0,1)(1,1,1)[7] intercept   : AIC=65628.993, Time=4.29 sec
#  ARIMA(2,0,1)(0,1,2)[7] intercept   : AIC=65629.107, Time=7.44 sec
#  ARIMA(2,0,1)(1,1,0)[7] intercept   : AIC=66068.833, Time=3.29 sec
#  ARIMA(2,0,1)(1,1,2)[7] intercept   : AIC=inf, Time=18.53 sec
#  ARIMA(2,0,0)(0,1,1)[7] intercept   : AIC=65639.924, Time=1.99 sec
#  ARIMA(3,0,1)(0,1,1)[7] intercept   : AIC=65621.665, Time=5.57 sec
#  ARIMA(3,0,1)(0,1,0)[7] intercept   : AIC=66650.351, Time=2.89 sec
#  ARIMA(3,0,1)(1,1,1)[7] intercept   : AIC=65623.646, Time=8.00 sec
#  ARIMA(3,0,1)(0,1,2)[7] intercept   : AIC=65623.640, Time=11.47 sec
#  ARIMA(3,0,1)(1,1,0)[7] intercept   : AIC=66068.925, Time=5.83 sec
#  ARIMA(3,0,1)(1,1,2)[7] intercept   : AIC=inf, Time=21.97 sec
#  ARIMA(3,0,0)(0,1,1)[7] intercept   : AIC=65625.149, Time=2.38 sec
#  ARIMA(3,0,2)(0,1,1)[7] intercept   : AIC=65589.247, Time=5.92 sec
#  ARIMA(3,0,2)(0,1,0)[7] intercept   : AIC=66545.821, Time=6.39 sec
#  ARIMA(3,0,2)(1,1,1)[7] intercept   : AIC=65591.120, Time=8.58 sec
#  ARIMA(3,0,2)(0,1,2)[7] intercept   : AIC=65591.230, Time=11.15 sec
#  ARIMA(3,0,2)(1,1,0)[7] intercept   : AIC=66056.621, Time=4.63 sec
#  ARIMA(3,0,2)(1,1,2)[7] intercept   : AIC=inf, Time=21.27 sec
#  ARIMA(2,0,2)(0,1,1)[7] intercept   : AIC=65618.591, Time=5.34 sec
#  ARIMA(3,0,3)(0,1,1)[7] intercept   : AIC=65445.369, Time=12.87 sec
#  ARIMA(3,0,3)(0,1,0)[7] intercept   : AIC=inf, Time=9.53 sec
#  ARIMA(3,0,3)(1,1,1)[7] intercept   : AIC=65447.433, Time=15.15 sec
#  ARIMA(3,0,3)(0,1,2)[7] intercept   : AIC=65447.222, Time=21.85 sec
#  ARIMA(3,0,3)(1,1,0)[7] intercept   : AIC=inf, Time=14.94 sec
#  ARIMA(3,0,3)(1,1,2)[7] intercept   : AIC=inf, Time=28.81 sec
#  ARIMA(2,0,3)(0,1,1)[7] intercept   : AIC=65508.058, Time=14.83 sec
#  ARIMA(3,0,3)(0,1,1)[7]             : AIC=65428.763, Time=6.68 sec
#  ARIMA(3,0,3)(0,1,0)[7]             : AIC=inf, Time=7.10 sec
#  ARIMA(3,0,3)(1,1,1)[7]             : AIC=65429.641, Time=12.78 sec
#  ARIMA(3,0,3)(0,1,2)[7]             : AIC=65429.636, Time=15.72 sec
#  ARIMA(3,0,3)(1,1,0)[7]             : AIC=inf, Time=16.49 sec
#  ARIMA(3,0,3)(1,1,2)[7]             : AIC=65430.881, Time=39.99 sec
#  ARIMA(2,0,3)(0,1,1)[7]             : AIC=65485.893, Time=15.43 sec
#  ARIMA(3,0,2)(0,1,1)[7]             : AIC=65568.290, Time=16.96 sec
#  ARIMA(2,0,2)(0,1,1)[7]             : AIC=65594.303, Time=4.47 sec
#
# Best model:  ARIMA(3,0,3)(0,1,1)[7]
# Total fit time: 448.166 seconds

# %%
mae = np.mean(np.abs(smodel_half.resid()))
mae
# Out:
# 26076.267743179218

# %% [markdown]
# ### Sarimax without exogenous

# %%
# !pip3 install pyramid-arima
import pmdarima as pm

# Seasonal - fit stepwise auto-ARIMA
smodel_light = pm.auto_arima(merged_dataset[['count']], 
                         start_p=1, start_q=1,
                         test='adf',
                         max_p=3, max_q=3, m=7,
                         start_P=0, seasonal=True,
                         d=None, D=1, trace=True,
                         error_action='ignore',  
                         suppress_warnings=True, 
                         stepwise=True)

# smodel_light.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,1,1)[7] intercept   : AIC=65635.003, Time=2.21 sec
#  ARIMA(0,0,0)(0,1,0)[7] intercept   : AIC=68399.422, Time=0.14 sec
#  ARIMA(1,0,0)(1,1,0)[7] intercept   : AIC=66074.137, Time=1.08 sec
#  ARIMA(0,0,1)(0,1,1)[7] intercept   : AIC=66918.156, Time=0.81 sec
#  ARIMA(0,0,0)(0,1,0)[7]             : AIC=68397.694, Time=0.11 sec
#  ARIMA(1,0,1)(0,1,0)[7] intercept   : AIC=66647.433, Time=0.61 sec
#  ARIMA(1,0,1)(1,1,1)[7] intercept   : AIC=65636.873, Time=2.27 sec
#  ARIMA(1,0,1)(0,1,2)[7] intercept   : AIC=65636.761, Time=10.14 sec
#  ARIMA(1,0,1)(1,1,0)[7] intercept   : AIC=66068.671, Time=2.84 sec
#  ARIMA(1,0,1)(1,1,2)[7] intercept   : AIC=inf, Time=28.07 sec
#  ARIMA(1,0,0)(0,1,1)[7] intercept   : AIC=65661.924, Time=2.74 sec
#  ARIMA(2,0,1)(0,1,1)[7] intercept   : AIC=65627.110, Time=6.31 sec
#  ARIMA(2,0,1)(0,1,0)[7] intercept   : AIC=66649.433, Time=2.99 sec
#  ARIMA(2,0,1)(1,1,1)[7] intercept   : AIC=65628.993, Time=8.99 sec
#  ARIMA(2,0,1)(0,1,2)[7] intercept   : AIC=65629.107, Time=14.62 sec
#  ARIMA(2,0,1)(1,1,0)[7] intercept   : AIC=66068.833, Time=6.06 sec
#  ARIMA(2,0,1)(1,1,2)[7] intercept   : AIC=inf, Time=22.78 sec
#  ARIMA(2,0,0)(0,1,1)[7] intercept   : AIC=65639.924, Time=2.03 sec
#  ARIMA(3,0,1)(0,1,1)[7] intercept   : AIC=65621.665, Time=6.20 sec
#  ARIMA(3,0,1)(0,1,0)[7] intercept   : AIC=66650.351, Time=2.20 sec
#  ARIMA(3,0,1)(1,1,1)[7] intercept   : AIC=65623.646, Time=8.61 sec
#  ARIMA(3,0,1)(0,1,2)[7] intercept   : AIC=65623.640, Time=12.37 sec
#  ARIMA(3,0,1)(1,1,0)[7] intercept   : AIC=66068.925, Time=6.01 sec
#  ARIMA(3,0,1)(1,1,2)[7] intercept   : AIC=inf, Time=23.48 sec
#  ARIMA(3,0,0)(0,1,1)[7] intercept   : AIC=65625.149, Time=2.97 sec
#  ARIMA(3,0,2)(0,1,1)[7] intercept   : AIC=65589.247, Time=7.77 sec
#  ARIMA(3,0,2)(0,1,0)[7] intercept   : AIC=66545.821, Time=7.56 sec
#  ARIMA(3,0,2)(1,1,1)[7] intercept   : AIC=65591.120, Time=9.53 sec
#  ARIMA(3,0,2)(0,1,2)[7] intercept   : AIC=65591.230, Time=13.32 sec
#  ARIMA(3,0,2)(1,1,0)[7] intercept   : AIC=66056.621, Time=5.10 sec
#  ARIMA(3,0,2)(1,1,2)[7] intercept   : AIC=inf, Time=29.42 sec
#  ARIMA(2,0,2)(0,1,1)[7] intercept   : AIC=65618.591, Time=6.98 sec
#  ARIMA(3,0,3)(0,1,1)[7] intercept   : AIC=65445.369, Time=14.13 sec
#  ARIMA(3,0,3)(0,1,0)[7] intercept   : AIC=inf, Time=10.80 sec
#  ARIMA(3,0,3)(1,1,1)[7] intercept   : AIC=65447.433, Time=21.44 sec
#  ARIMA(3,0,3)(0,1,2)[7] intercept   : AIC=65447.222, Time=27.12 sec
#  ARIMA(3,0,3)(1,1,0)[7] intercept   : AIC=inf, Time=16.71 sec
#  ARIMA(3,0,3)(1,1,2)[7] intercept   : AIC=inf, Time=29.27 sec
#  ARIMA(2,0,3)(0,1,1)[7] intercept   : AIC=65508.058, Time=12.64 sec
#  ARIMA(3,0,3)(0,1,1)[7]             : AIC=65428.763, Time=6.93 sec
#  ARIMA(3,0,3)(0,1,0)[7]             : AIC=inf, Time=8.70 sec
#  ARIMA(3,0,3)(1,1,1)[7]             : AIC=65429.641, Time=9.47 sec
#  ARIMA(3,0,3)(0,1,2)[7]             : AIC=65429.636, Time=13.37 sec
#  ARIMA(3,0,3)(1,1,0)[7]             : AIC=inf, Time=14.79 sec
#  ARIMA(3,0,3)(1,1,2)[7]             : AIC=65430.881, Time=24.41 sec
#  ARIMA(2,0,3)(0,1,1)[7]             : AIC=65485.893, Time=9.48 sec
#  ARIMA(3,0,2)(0,1,1)[7]             : AIC=65568.290, Time=11.46 sec
#  ARIMA(2,0,2)(0,1,1)[7]             : AIC=65594.303, Time=4.40 sec
#
# Best model:  ARIMA(3,0,3)(0,1,1)[7]
# Total fit time: 491.516 seconds

# %%
mae = np.mean(np.abs(smodel_light.resid()))
mae
# Out:
# 26076.267743179218

# %%
smodel_full.resid()[1]
# Out:
# 93006.46826897562

# %%
smodel_half.resid()[1]
# Out:
# 93006.46826897562
